# %% [markdown]
# # Ghana Financial Inclusion Analysis
#
# ## The Global Findex 2025
#
# **Country:** Ghana
# **Survey year:** 2024
# **Data source:** World Bank Global Findex Database 2025
#
# ### Research Focus
#
# This project examines financial inclusion and digital financial services in Ghana, with particular attention to mobile money, formal financial accounts, savings, digital payments and socioeconomic characteristics.
#
# ### Research Questions
#
# 1. What are the patterns of financial inclusion in Ghana?
# 2. How widespread is mobile-money account ownership?
# 3. How does financial inclusion vary by gender?
# 4. How does financial inclusion vary by socioeconomic characteristics?
# 5. What implications do the findings have for financial inclusion policy in Ghana?

# %%
print("Ghana Financial Inclusion Analysis")
print("World Bank Global Findex 2025")
# Out:
# Ghana Financial Inclusion Analysis
# World Bank Global Findex 2025

# %% [markdown]
# # MODULES IMPORT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data

df = pd.read_csv("Findex_Microdata_2025_updateGhana.csv")

# %%
# inspect dimensions of the data
df.shape
# Out:
# (1000, 199)

# %%
# view the first 3 top row of the data
df.head(3)
# Out:
#    year economy economycode                                    regionwb  \
# 0  2024   Ghana         GHA  Sub-Saharan Africa (excluding high income)
# 1  2024   Ghana         GHA  Sub-Saharan Africa (excluding high income)
# 2  2024   Ghana         GHA  Sub-Saharan Africa (excluding high income)
#
#    pop_adult  wpid_random       wgt  female  age  educ  ...  fin48e  fin48f  \
# 0   21563813    111377352  1.757570       1   45   2.0  ...     NaN     NaN
# 1   21563813    111425422  0.905216       1   37   2.0  ...     NaN     NaN
# 2   21563813    111524531  3.010035       1   53   1.0  ...     NaN     NaN
#
#    fin49a  fin49b  fin49c  fin49d  fin49e  fin49f  fin50  fin51
# 0     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN    NaN    NaN
#
# [3 rows x 199 columns]

# %%
# inspect the 199 variables

df.columns.tolist()
# Out:
# ['year',
#  'economy',
#  'economycode',
#  'regionwb',
#  'pop_adult',
#  'wpid_random',
#  'wgt',
#  'female',
#  'age',
#  'educ',
#  'inc_q',
#  'emp_in',
#  'urbanicity',
#  'account_fin',
#  'account_mob',
#  'account',
#  'dig_account',
#  'borrowed',
#  'saved',
#  'receive_wages',
#  'receive_transfers',
#  'receive_pensions',
#  'receive_agriculture',
#  'merchantpay_dig',
#  'pay_utilities',
#  'domestic_remittances',
#  'anydigpayment',
#  'fin2',
#  'fin3',
#  'fin4',
#  'fin5',
#  'fin6',
#  'fin7',
#  'fin8',
#  'fin9a',
#  'fin9b',
#  'fin10',
#  'fin11_0',
#  'fin11_1',
#  'fin11_2',
#  'fin11a',
#  'fin11b',
#  'fin11c',
#  'fin11d',
#  'fin11e',
#  'fin11f',
#  'fin13_1',
#  'fin13a',
#  'fin13b',
#  'fin13c',
#  'fin13d',
#  'fin13e',
#  'fin13f',
#  'fin13f_1',
#  'fin14a',
#  'fin14b',
#  'fin14c',
#  'fin14d',
#  'fin14e',
#  'fin15',
#  'fin16',
#  'fin17a',
#  'fin17b',
#  'fin17c',
#  'fin17d',
#  'fin17e',
#  'fin17f',
#  'fin18',
#  'fin19',
#  'fin20',
# ...

# %%
# look at the distribution
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 199 entries, year to fin51
# dtypes: float64(149), int64(47), object(3)
# memory usage: 1.5+ MB

# %%
# Distribution of mobile money account ownership

df["account_mob"].value_counts(dropna=False)
# Out:
# account_mob
# 1    818
# 0    182
# Name: count, dtype: int64

# %%
# convert the frequency to %
df["account_mob"].value_counts(normalize=True, dropna=False) * 100
# Out:
# account_mob
# 1    81.8
# 0    18.2
# Name: proportion, dtype: float64
